# %% [markdown]
# # Motion Data Amplitude Analysis
#
# 指定キロ周辺の全振幅を時系列でプロット（波形表示付き）
#
# ## メイン機能
# `plot_max_amplitude_timeseries_with_waveforms()` - 全振幅時系列分析と波形表示

# %%
# ライブラリのインポート
from amplitude_analysis import plot_max_amplitude_timeseries_with_waveforms

print("全振幅分析ツールを読み込みました。")
# Out:
# 全振幅分析ツールを読み込みました。

# %% [markdown]
# ## 基本的な使用例
#
# 以下のセルで、任意のキロ地点での全振幅分析を実行できます。
#
# **パラメータ説明：**
# - `target_kilo`: 分析対象キロ地点
# - `kilo_range`: 全振幅抽出範囲（±）
# - `plot_kilo_start/end`: 波形表示範囲

# %%
# 基本的な全振幅分析の実行
# target_kilo=283.09
# target_kilo=283.355
# target_kilo=283.487
target_kilo=244.738

result = plot_max_amplitude_timeseries_with_waveforms(
    target_kilo=target_kilo,      # 分析対象キロ
    kilo_range=0.005,        # 全振幅抽出範囲（±0.005m）
    plot_kilo_start=target_kilo-0.25,   # 波形表示開始キロ
    plot_kilo_end=target_kilo+0.25,      # 波形表示終了キロ
    analysis_kilo_start=target_kilo-0.25,  # 分析開始キロ
    analysis_kilo_end=target_kilo+0.25,    # 分析終了キロ
    figsize=(16, 24)          # グラフのサイズ
)
# Out:
# === 全振幅時系列分析（波形表示付き） ===
# ターゲットキロ: 244.738
# 全振幅抽出範囲: ±0.005m
# \nデータ読み込み・補正処理中...
#   data1を処理中...
# 分析範囲で検出された極値の数: 74
# 区間 1 (Kilo: 244.50-244.51): 最適なShift = 0.0045, 最大相関 = 0.5237
# 区間 2 (Kilo: 244.51-244.51): 最適なShift = 0.0045, 最大相関 = 0.2947
# 区間 3 (Kilo: 244.51-244.52): 最適なShift = -0.0011, 最大相関 = -0.0046
# 区間 4 (Kilo: 244.51-244.52): 最適なShift = 0.0006, 最大相関 = 0.9308
# 区間 5 (Kilo: 244.52-244.53): 最適なShift = 0.0009, 最大相関 = 0.9469
# 区間 6 (Kilo: 244.52-244.53): 最適なShift = -0.0002, 最大相関 = -0.1949
# 区間 7 (Kilo: 244.53-244.54): 最適なShift = -0.0037, 最大相関 = 0.7659
# 区間 8 (Kilo: 244.53-244.54): 最適なShift = -0.0027, 最大相関 = 0.6282
# 区間 9 (Kilo: 244.54-244.55): 最適なShift = 0.0002, 最大相関 = 0.9891
# 区間 10 (Kilo: 244.54-244.55): 最適なShift = 0.0012, 最大相関 = 0.7796
# 区間 11 (Kilo: 244.55-244.56): 最適なShift = -0.0002, 最大相関 = -0.1628
# 区間 12 (Kilo: 244.55-244.56): 最適なShift = -0.0035, 最大相関 = 0.5543
# 区間 13 (Kilo: 244.55-244.57): 最適なShift = -0.0012, 最大相関 = 0.9734
# 区間 14 (Kilo: 244.56-244.57): 最適なShift = 0.0042, 最大相関 = 0.5923
# 区間 15 (Kilo: 244.57-244.58): 最適なShift = 0.0030, 最大相関 = 0.8901
# 区間 16 (Kilo: 244.58-244.58): 最適なShift = -0.0007, 最大相関 = 0.1672
# 区間 17 (Kilo: 244.58-244.59): 最適なShift = -0.0036, 最大相関 = 0.9228
# 区間 18 (Kilo: 244.58-244.60): 最適なShift = -0.0025, 最大相関 = 0.8386
# 区間 19 (Kilo: 244.59-244.61): 最適なShift = 0.0001, 最大相関 = 0.9455
# 区間 20 (Kilo: 244.60-244.61): 最適なShift = 0.0011, 最大相関 = 0.9977
# 区間 21 (Kilo: 244.61-244.62): 最適なShift = 0.0015, 最大相関 = 0.9074
# 区間 22 (Kilo: 244.61-244.63): 最適なShift = -0.0028, 最大相関 = 0.8605
# 区間 23 (Kilo: 244.62-244.64): 最適なShift = 0.0041, 最大相関 = 0.9132
# 区間 24 (Kilo: 244.63-244.64): 最適なShift = -0.0001, 最大相関 = 0.6418
# 区間 25 (Kilo: 244.64-244.65): 最適なShift = 0.0016, 最大相関 = 0.9741
# 区間 26 (Kilo: 244.64-244.67): 最適なShift = 0.0006, 最大相関 = 0.9923
# 区間 27 (Kilo: 244.65-244.68): 最適なShift = -0.0003, 最大相関 = 0.9901
# 区間 28 (Kilo: 244.67-244.68): 最適なShift = 0.0002, 最大相関 = 0.9974
# 区間 29 (Kilo: 244.68-244.70): 最適なShift = -0.0011, 最大相関 = 0.9016
# 区間 30 (Kilo: 244.68-244.70): 最適なShift = -0.0032, 最大相関 = 0.9739
# 区間 31 (Kilo: 244.69-244.71): 最適なShift = -0.0023, 最大相関 = 0.9462
# 区間 32 (Kilo: 244.70-244.72): 最適なShift = -0.0015, 最大相関 = 0.9985
# 区間 33 (Kilo: 244.71-244.72): 最適なShift = 0.0001, 最大相関 = 0.9904
# 区間 34 (Kilo: 244.72-244.72): 最適なShift = 0.0015, 最大相関 = 0.9905
# 区間 35 (Kilo: 244.72-244.73): 最適なShift = 0.0037, 最大相関 = -0.6981
# 区間 36 (Kilo: 244.73-244.74): 最適なShift = -0.0009, 最大相関 = 0.9212
# 区間 37 (Kilo: 244.73-244.74): 最適なShift = -0.0022, 最大相関 = 0.8572
# 区間 38 (Kilo: 244.73-244.75): 最適なShift = 0.0004, 最大相関 = 0.9531
# 区間 39 (Kilo: 244.74-244.75): 最適なShift = 0.0007, 最大相関 = 0.9146
# 区間 40 (Kilo: 244.75-244.76): 最適なShift = -0.0002, 最大相関 = -0.4049
# 区間 41 (Kilo: 244.75-244.76): 最適なShift = -0.0069, 最大相関 = 0.6262
# 区間 42 (Kilo: 244.75-244.77): 最適なShift = -0.0052, 最大相関 = 0.7105
# 区間 43 (Kilo: 244.76-244.77): 最適なShift = -0.0061, 最大相関 = 0.8481
# 区間 44 (Kilo: 244.76-244.78): 最適なShift = -0.0033, 最大相関 = 0.9466
# 区間 45 (Kilo: 244.77-244.79): 最適なShift = -0.0038, 最大相関 = 0.8979
# 区間 46 (Kilo: 244.78-244.80): 最適なShift = -0.0050, 最大相関 = 0.9745
# 区間 47 (Kilo: 244.79-244.81): 最適なShift = -0.0038, 最大相関 = 0.9779
# 区間 48 (Kilo: 244.80-244.82): 最適なShift = -0.0033, 最大相関 = 0.9607
# 区間 49 (Kilo: 244.81-244.84): 最適なShift = -0.0037, 最大相関 = 0.8998
# 区間 50 (Kilo: 244.82-244.84): 最適なShift = -0.0062, 最大相関 = 0.9138
# 区間 51 (Kilo: 244.83-244.85): 最適なShift = -0.0069, 最大相関 = 0.9409
# 区間 52 (Kilo: 244.84-244.85): 最適なShift = -0.0074, 最大相関 = 0.6182
# 区間 53 (Kilo: 244.84-244.85): 最適なShift = 0.0028, 最大相関 = -0.3533
# 区間 54 (Kilo: 244.85-244.86): 最適なShift = 0.0030, 最大相関 = 0.5233
# 区間 55 (Kilo: 244.86-244.86): 最適なShift = -0.0007, 最大相関 = -0.4730
# 区間 56 (Kilo: 244.86-244.86): 最適なShift = 0.0015, 最大相関 = 0.8849
# 区間 57 (Kilo: 244.86-244.87): 最適なShift = 0.0052, 最大相関 = -0.7500
# 区間 58 (Kilo: 244.87-244.88): 最適なShift = -0.0013, 最大相関 = 0.4003
# 区間 59 (Kilo: 244.87-244.88): 最適なShift = -0.0053, 最大相関 = 0.8239
# 区間 60 (Kilo: 244.87-244.89): 最適なShift = 0.0030, 最大相関 = 0.6046
# 区間 61 (Kilo: 244.89-244.89): 最適なShift = 0.0027, 最大相関 = -0.1619
# 区間 62 (Kilo: 244.89-244.91): 最適なShift = -0.0032, 最大相関 = 0.3355
# 区間 63 (Kilo: 244.89-244.91): 最適なShift = -0.0086, 最大相関 = 0.9260
# 区間 64 (Kilo: 244.90-244.93): 最適なShift = -0.0039, 最大相関 = 0.6352
# 区間 65 (Kilo: 244.91-244.94): 最適なShift = -0.0066, 最大相関 = 0.8617
# 区間 66 (Kilo: 244.92-244.95): 最適なShift = -0.0037, 最大相関 = 0.9511
# 区間 67 (Kilo: 244.93-244.96): 最適なShift = -0.0052, 最大相関 = 0.9494
# 区間 68 (Kilo: 244.94-244.96): 最適なShift = 0.0022, 最大相関 = 0.9597
# 区間 69 (Kilo: 244.96-244.96): 最適なShift = 0.0037, 最大相関 = -0.0383
# 区間 70 (Kilo: 244.96-244.97): 最適なShift = -0.0009, 最大相関 = 0.0254
# 区間 71 (Kilo: 244.96-244.98): 最適なShift = -0.0067, 最大相関 = 0.2427
# 区間 72 (Kilo: 244.97-244.98): 最適なShift = -0.0052, 最大相関 = 0.4812
#   data2を処理中...
# 分析範囲で検出された極値の数: 60
# 区間 1 (Kilo: 244.50-244.52): 最適なShift = -0.0064, 最大相関 = 0.8088
# 区間 2 (Kilo: 244.51-244.53): 最適なShift = -0.0052, 最大相関 = 0.8673
# 区間 3 (Kilo: 244.52-244.54): 最適なShift = -0.0086, 最大相関 = 0.6349
# 区間 4 (Kilo: 244.52-244.55): 最適なShift = -0.0053, 最大相関 = 0.2454
# 区間 5 (Kilo: 244.53-244.56): 最適なShift = -0.0050, 最大相関 = 0.0505
# 区間 6 (Kilo: 244.54-244.56): 最適なShift = -0.0102, 最大相関 = 0.8822
# 区間 7 (Kilo: 244.55-244.57): 最適なShift = -0.0038, 最大相関 = 0.8301
# 区間 8 (Kilo: 244.56-244.58): 最適なShift = -0.0054, 最大相関 = 0.7540
# 区間 9 (Kilo: 244.57-244.59): 最適なShift = -0.0059, 最大相関 = 0.7948
# 区間 10 (Kilo: 244.58-244.60): 最適なShift = -0.0038, 最大相関 = 0.8398
# 区間 11 (Kilo: 244.59-244.60): 最適なShift = -0.0018, 最大相関 = 0.9393
# 区間 12 (Kilo: 244.59-244.60): 最適なShift = 0.0022, 最大相関 = 0.5948
# 区間 13 (Kilo: 244.60-244.61): 最適なShift = -0.0006, 最大相関 = 0.6569
# 区間 14 (Kilo: 244.60-244.61): 最適なShift = -0.0035, 最大相関 = 0.9622
# 区間 15 (Kilo: 244.60-244.62): 最適なShift = -0.0013, 最大相関 = 0.3886
# 区間 16 (Kilo: 244.61-244.63): 最適なShift = -0.0054, 最大相関 = 0.5265
# 区間 17 (Kilo: 244.62-244.63): 最適なShift = -0.0025, 最大相関 = 0.9018
# 区間 18 (Kilo: 244.62-244.64): 最適なShift = -0.0049, 最大相関 = -0.5517
# 区間 19 (Kilo: 244.63-244.64): 最適なShift = -0.0070, 最大相関 = -0.1904
# 区間 20 (Kilo: 244.63-244.65): 最適なShift = -0.0064, 最大相関 = 0.3267
# 区間 21 (Kilo: 244.64-244.66): 最適なShift = -0.0091, 最大相関 = 0.4134
# 区間 22 (Kilo: 244.64-244.67): 最適なShift = -0.0074, 最大相関 = 0.8393
# 区間 23 (Kilo: 244.65-244.68): 最適なShift = -0.0068, 最大相関 = 0.7166
# 区間 24 (Kilo: 244.66-244.69): 最適なShift = -0.0065, 最大相関 = 0.7824
# 区間 25 (Kilo: 244.67-244.70): 最適なShift = -0.0059, 最大相関 = 0.6970
# 区間 26 (Kilo: 244.68-244.71): 最適なShift = -0.0069, 最大相関 = 0.8799
# 区間 27 (Kilo: 244.69-244.71): 最適なShift = -0.0055, 最大相関 = 0.7978
# 区間 28 (Kilo: 244.70-244.72): 最適なShift = -0.0057, 最大相関 = 0.7194
# 区間 29 (Kilo: 244.71-244.73): 最適なShift = -0.0061, 最大相関 = 0.5812
# 区間 30 (Kilo: 244.71-244.74): 最適なShift = -0.0083, 最大相関 = 0.9129
# 区間 31 (Kilo: 244.72-244.75): 最適なShift = -0.0062, 最大相関 = 0.8239
# 区間 32 (Kilo: 244.73-244.76): 最適なShift = -0.0049, 最大相関 = 0.8767
# 区間 33 (Kilo: 244.74-244.77): 最適なShift = -0.0050, 最大相関 = 0.7878
# 区間 34 (Kilo: 244.75-244.77): 最適なShift = -0.0070, 最大相関 = 0.1045
# 区間 35 (Kilo: 244.76-244.78): 最適なShift = -0.0090, 最大相関 = 0.0968
# 区間 36 (Kilo: 244.76-244.78): 最適なShift = -0.0074, 最大相関 = 0.7632
# 区間 37 (Kilo: 244.77-244.80): 最適なShift = -0.0080, 最大相関 = 0.7258
# 区間 38 (Kilo: 244.78-244.80): 最適なShift = -0.0086, 最大相関 = 0.8664
# 区間 39 (Kilo: 244.79-244.82): 最適なShift = -0.0080, 最大相関 = 0.7728
# 区間 40 (Kilo: 244.80-244.83): 最適なShift = -0.0068, 最大相関 = 0.8918
# 区間 41 (Kilo: 244.81-244.84): 最適なShift = -0.0083, 最大相関 = 0.8481
# 区間 42 (Kilo: 244.82-244.85): 最適なShift = -0.0100, 最大相関 = 0.8720
# 区間 43 (Kilo: 244.83-244.86): 最適なShift = 0.0040, 最大相関 = 0.7840
# 区間 44 (Kilo: 244.85-244.86): 最適なShift = 0.0045, 最大相関 = 0.6168
# 区間 45 (Kilo: 244.86-244.87): 最適なShift = 0.0067, 最大相関 = -0.2672
# 区間 46 (Kilo: 244.87-244.88): 最適なShift = -0.0017, 最大相関 = -0.3694
# 区間 47 (Kilo: 244.87-244.89): 最適なShift = -0.0103, 最大相関 = 0.6017
# 区間 48 (Kilo: 244.87-244.90): 最適なShift = -0.0057, 最大相関 = 0.8991
# 区間 49 (Kilo: 244.88-244.91): 最適なShift = -0.0051, 最大相関 = 0.9490
# 区間 50 (Kilo: 244.90-244.91): 最適なShift = 0.0030, 最大相関 = -0.2181
# 区間 51 (Kilo: 244.91-244.92): 最適なShift = 0.0060, 最大相関 = -0.7298
# 区間 52 (Kilo: 244.92-244.93): 最適なShift = 0.0105, 最大相関 = -0.2417
# 区間 53 (Kilo: 244.93-244.94): 最適なShift = 0.0060, 最大相関 = 0.1240
# 区間 54 (Kilo: 244.94-244.95): 最適なShift = -0.0015, 最大相関 = 0.0126
# 区間 55 (Kilo: 244.94-244.97): 最適なShift = -0.0083, 最大相関 = 0.3543
# 区間 56 (Kilo: 244.94-244.97): 最適なShift = -0.0060, 最大相関 = 0.8264
# 区間 57 (Kilo: 244.96-244.98): 最適なShift = -0.0028, 最大相関 = 0.8177
# 区間 58 (Kilo: 244.97-244.99): 最適なShift = -0.0025, 最大相関 = -0.2233
#   data3を処理中...
# 分析範囲で検出された極値の数: 62
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = -0.0052, 最大相関 = -0.5143
# 区間 2 (Kilo: 244.49-244.51): 最適なShift = -0.0092, 最大相関 = 0.7635
# 区間 3 (Kilo: 244.50-244.52): 最適なShift = -0.0056, 最大相関 = 0.9522
# 区間 4 (Kilo: 244.51-244.53): 最適なShift = -0.0027, 最大相関 = 0.8384
# 区間 5 (Kilo: 244.52-244.54): 最適なShift = -0.0053, 最大相関 = 0.7203
# 区間 6 (Kilo: 244.52-244.55): 最適なShift = -0.0046, 最大相関 = 0.1413
# 区間 7 (Kilo: 244.54-244.55): 最適なShift = -0.0063, 最大相関 = 0.7887
# 区間 8 (Kilo: 244.54-244.56): 最適なShift = 0.0017, 最大相関 = 0.9610
# 区間 9 (Kilo: 244.55-244.57): 最適なShift = 0.0001, 最大相関 = 0.9556
# 区間 10 (Kilo: 244.56-244.58): 最適なShift = -0.0029, 最大相関 = 0.9641
# 区間 11 (Kilo: 244.57-244.58): 最適なShift = 0.0015, 最大相関 = 0.9559
# 区間 12 (Kilo: 244.58-244.59): 最適なShift = 0.0022, 最大相関 = 0.6064
# 区間 13 (Kilo: 244.58-244.59): 最適なShift = -0.0006, 最大相関 = -0.5861
# 区間 14 (Kilo: 244.58-244.60): 最適なShift = -0.0042, 最大相関 = 0.6507
# 区間 15 (Kilo: 244.59-244.61): 最適なShift = 0.0003, 最大相関 = 0.9645
# 区間 16 (Kilo: 244.60-244.61): 最適なShift = 0.0003, 最大相関 = 0.9951
# 区間 17 (Kilo: 244.61-244.62): 最適なShift = 0.0000, 最大相関 = 0.9497
# 区間 18 (Kilo: 244.61-244.63): 最適なShift = -0.0030, 最大相関 = 0.7817
# 区間 19 (Kilo: 244.62-244.64): 最適なShift = -0.0010, 最大相関 = 0.8551
# 区間 20 (Kilo: 244.63-244.65): 最適なShift = -0.0020, 最大相関 = 0.9686
# 区間 21 (Kilo: 244.64-244.65): 最適なShift = -0.0013, 最大相関 = 0.8320
# 区間 22 (Kilo: 244.64-244.66): 最適なShift = 0.0021, 最大相関 = 0.9030
# 区間 23 (Kilo: 244.66-244.66): 最適なShift = 0.0030, 最大相関 = 0.9402
# 区間 24 (Kilo: 244.66-244.67): 最適なShift = 0.0030, 最大相関 = 0.0923
# 区間 25 (Kilo: 244.67-244.68): 最適なShift = -0.0007, 最大相関 = 0.8811
# 区間 26 (Kilo: 244.67-244.69): 最適なShift = -0.0047, 最大相関 = 0.9361
# 区間 27 (Kilo: 244.67-244.70): 最適なShift = -0.0034, 最大相関 = 0.9404
# 区間 28 (Kilo: 244.68-244.70): 最適なShift = -0.0037, 最大相関 = 0.9624
# 区間 29 (Kilo: 244.69-244.71): 最適なShift = -0.0033, 最大相関 = 0.9677
# 区間 30 (Kilo: 244.70-244.72): 最適なShift = -0.0031, 最大相関 = 0.9888
# 区間 31 (Kilo: 244.71-244.73): 最適なShift = -0.0013, 最大相関 = 0.9145
# 区間 32 (Kilo: 244.72-244.74): 最適なShift = -0.0047, 最大相関 = 0.9764
# 区間 33 (Kilo: 244.72-244.75): 最適なShift = -0.0037, 最大相関 = 0.9548
# 区間 34 (Kilo: 244.73-244.76): 最適なShift = -0.0033, 最大相関 = 0.9416
# 区間 35 (Kilo: 244.74-244.76): 最適なShift = -0.0034, 最大相関 = 0.9261
# 区間 36 (Kilo: 244.75-244.77): 最適なShift = -0.0040, 最大相関 = 0.3470
# 区間 37 (Kilo: 244.76-244.77): 最適なShift = -0.0067, 最大相関 = 0.4843
# 区間 38 (Kilo: 244.76-244.78): 最適なShift = -0.0056, 最大相関 = 0.8723
# 区間 39 (Kilo: 244.77-244.79): 最適なShift = -0.0048, 最大相関 = 0.9251
# 区間 40 (Kilo: 244.78-244.80): 最適なShift = -0.0052, 最大相関 = 0.9051
# 区間 41 (Kilo: 244.79-244.81): 最適なShift = -0.0061, 最大相関 = 0.9233
# 区間 42 (Kilo: 244.80-244.82): 最適なShift = -0.0049, 最大相関 = 0.9359
# 区間 43 (Kilo: 244.81-244.84): 最適なShift = -0.0052, 最大相関 = 0.9408
# 区間 44 (Kilo: 244.82-244.84): 最適なShift = -0.0064, 最大相関 = 0.8350
# 区間 45 (Kilo: 244.83-244.85): 最適なShift = -0.0069, 最大相関 = 0.7853
# 区間 46 (Kilo: 244.84-244.86): 最適なShift = -0.0080, 最大相関 = -0.1799
# 区間 47 (Kilo: 244.84-244.87): 最適なShift = -0.0096, 最大相関 = 0.7408
# 区間 48 (Kilo: 244.85-244.88): 最適なShift = -0.0071, 最大相関 = 0.9750
# 区間 49 (Kilo: 244.86-244.89): 最適なShift = -0.0026, 最大相関 = 0.9783
# 区間 50 (Kilo: 244.87-244.89): 最適なShift = -0.0021, 最大相関 = 0.9891
# 区間 51 (Kilo: 244.88-244.90): 最適なShift = -0.0032, 最大相関 = -0.0053
# 区間 52 (Kilo: 244.89-244.91): 最適なShift = -0.0054, 最大相関 = 0.8958
# 区間 53 (Kilo: 244.89-244.92): 最適なShift = -0.0069, 最大相関 = 0.7740
# 区間 54 (Kilo: 244.90-244.93): 最適なShift = -0.0049, 最大相関 = 0.8157
# 区間 55 (Kilo: 244.91-244.94): 最適なShift = -0.0075, 最大相関 = 0.8508
# 区間 56 (Kilo: 244.92-244.95): 最適なShift = -0.0057, 最大相関 = 0.9469
# 区間 57 (Kilo: 244.93-244.96): 最適なShift = -0.0051, 最大相関 = 0.9354
# 区間 58 (Kilo: 244.94-244.97): 最適なShift = -0.0008, 最大相関 = 0.9258
# 区間 59 (Kilo: 244.96-244.98): 最適なShift = -0.0023, 最大相関 = 0.9073
# 区間 60 (Kilo: 244.97-244.98): 最適なShift = -0.0027, 最大相関 = 0.2867
#   data4を処理中...
# 分析範囲で検出された極値の数: 59
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = -0.0035, 最大相関 = 0.7858
# 区間 2 (Kilo: 244.50-244.52): 最適なShift = -0.0009, 最大相関 = 0.9089
# 区間 3 (Kilo: 244.51-244.53): 最適なShift = -0.0031, 最大相関 = 0.7350
# 区間 4 (Kilo: 244.52-244.54): 最適なShift = -0.0080, 最大相関 = 0.8071
# 区間 5 (Kilo: 244.52-244.54): 最適なShift = -0.0030, 最大相関 = 0.5679
# 区間 6 (Kilo: 244.54-244.55): 最適なShift = -0.0022, 最大相関 = 0.4790
# 区間 7 (Kilo: 244.54-244.56): 最適なShift = 0.0005, 最大相関 = 0.8640
# 区間 8 (Kilo: 244.55-244.57): 最適なShift = 0.0008, 最大相関 = 0.9428
# 区間 9 (Kilo: 244.56-244.58): 最適なShift = 0.0006, 最大相関 = 0.9465
# 区間 10 (Kilo: 244.57-244.58): 最適なShift = 0.0017, 最大相関 = 0.9662
# 区間 11 (Kilo: 244.58-244.60): 最適なShift = 0.0012, 最大相関 = 0.8165
# 区間 12 (Kilo: 244.59-244.60): 最適なShift = -0.0051, 最大相関 = 0.8245
# 区間 13 (Kilo: 244.59-244.61): 最適なShift = 0.0028, 最大相関 = 0.8459
# 区間 14 (Kilo: 244.61-244.62): 最適なShift = 0.0023, 最大相関 = 0.6075
# 区間 15 (Kilo: 244.61-244.62): 最適なShift = 0.0013, 最大相関 = 0.9795
# 区間 16 (Kilo: 244.62-244.63): 最適なShift = -0.0002, 最大相関 = 0.9947
# 区間 17 (Kilo: 244.62-244.63): 最適なShift = 0.0031, 最大相関 = 0.9559
# 区間 18 (Kilo: 244.63-244.64): 最適なShift = -0.0011, 最大相関 = 0.9301
# 区間 19 (Kilo: 244.63-244.65): 最適なShift = -0.0018, 最大相関 = 0.7750
# 区間 20 (Kilo: 244.64-244.66): 最適なShift = -0.0022, 最大相関 = 0.9453
# 区間 21 (Kilo: 244.64-244.67): 最適なShift = -0.0024, 最大相関 = 0.9826
# 区間 22 (Kilo: 244.65-244.68): 最適なShift = -0.0016, 最大相関 = 0.9549
# 区間 23 (Kilo: 244.66-244.69): 最適なShift = -0.0032, 最大相関 = 0.9585
# 区間 24 (Kilo: 244.68-244.69): 最適なShift = -0.0016, 最大相関 = 0.9942
# 区間 25 (Kilo: 244.68-244.70): 最適なShift = -0.0007, 最大相関 = 0.9730
# 区間 26 (Kilo: 244.69-244.71): 最適なShift = -0.0013, 最大相関 = 0.9950
# 区間 27 (Kilo: 244.70-244.72): 最適なShift = -0.0002, 最大相関 = 0.9859
# 区間 28 (Kilo: 244.71-244.73): 最適なShift = -0.0013, 最大相関 = 0.8814
# 区間 29 (Kilo: 244.72-244.74): 最適なShift = -0.0042, 最大相関 = 0.9775
# 区間 30 (Kilo: 244.73-244.75): 最適なShift = -0.0015, 最大相関 = 0.9844
# 区間 31 (Kilo: 244.74-244.76): 最適なShift = -0.0025, 最大相関 = 0.9396
# 区間 32 (Kilo: 244.74-244.76): 最適なShift = -0.0036, 最大相関 = 0.9527
# 区間 33 (Kilo: 244.75-244.77): 最適なShift = -0.0038, 最大相関 = 0.5886
# 区間 34 (Kilo: 244.76-244.77): 最適なShift = -0.0061, 最大相関 = 0.7246
# 区間 35 (Kilo: 244.76-244.78): 最適なShift = -0.0043, 最大相関 = 0.9259
# 区間 36 (Kilo: 244.77-244.79): 最適なShift = -0.0043, 最大相関 = 0.9090
# 区間 37 (Kilo: 244.78-244.80): 最適なShift = -0.0054, 最大相関 = 0.9693
# 区間 38 (Kilo: 244.79-244.81): 最適なShift = -0.0038, 最大相関 = 0.9637
# 区間 39 (Kilo: 244.80-244.82): 最適なShift = -0.0029, 最大相関 = 0.9938
# 区間 40 (Kilo: 244.81-244.84): 最適なShift = -0.0024, 最大相関 = 0.8893
# 区間 41 (Kilo: 244.82-244.84): 最適なShift = -0.0069, 最大相関 = 0.9464
# 区間 42 (Kilo: 244.83-244.85): 最適なShift = -0.0055, 最大相関 = 0.6742
# 区間 43 (Kilo: 244.84-244.86): 最適なShift = -0.0087, 最大相関 = 0.0687
# 区間 44 (Kilo: 244.84-244.87): 最適なShift = -0.0091, 最大相関 = 0.8552
# 区間 45 (Kilo: 244.85-244.88): 最適なShift = -0.0060, 最大相関 = 0.9106
# 区間 46 (Kilo: 244.86-244.89): 最適なShift = -0.0057, 最大相関 = 0.9892
# 区間 47 (Kilo: 244.87-244.90): 最適なShift = -0.0024, 最大相関 = 0.9479
# 区間 48 (Kilo: 244.89-244.90): 最適なShift = -0.0005, 最大相関 = 0.9654
# 区間 49 (Kilo: 244.90-244.91): 最適なShift = 0.0030, 最大相関 = 0.0615
# 区間 50 (Kilo: 244.91-244.92): 最適なShift = -0.0007, 最大相関 = 0.1557
# 区間 51 (Kilo: 244.91-244.93): 最適なShift = -0.0064, 最大相関 = 0.3977
# 区間 52 (Kilo: 244.91-244.94): 最適なShift = -0.0102, 最大相関 = 0.6946
# 区間 53 (Kilo: 244.92-244.95): 最適なShift = -0.0079, 最大相関 = 0.8999
# 区間 54 (Kilo: 244.93-244.96): 最適なShift = -0.0071, 最大相関 = 0.8869
# 区間 55 (Kilo: 244.94-244.97): 最適なShift = -0.0058, 最大相関 = 0.9418
# 区間 56 (Kilo: 244.96-244.98): 最適なShift = -0.0033, 最大相関 = 0.9154
# 区間 57 (Kilo: 244.97-244.99): 最適なShift = -0.0037, 最大相関 = 0.0138
#   data5を処理中...
# 分析範囲で検出された極値の数: 58
# 区間 1 (Kilo: 244.49-244.50): 最適なShift = -0.0030, 最大相関 = 0.2015
# 区間 2 (Kilo: 244.49-244.51): 最適なShift = -0.0033, 最大相関 = 0.9854
# 区間 3 (Kilo: 244.50-244.52): 最適なShift = -0.0006, 最大相関 = 0.9582
# 区間 4 (Kilo: 244.51-244.52): 最適なShift = 0.0041, 最大相関 = 0.6737
# 区間 5 (Kilo: 244.52-244.53): 最適なShift = 0.0020, 最大相関 = 0.6409
# 区間 6 (Kilo: 244.52-244.54): 最適なShift = 0.0052, 最大相関 = 0.6412
# 区間 7 (Kilo: 244.54-244.55): 最適なShift = 0.0015, 最大相関 = 0.8875
# 区間 8 (Kilo: 244.54-244.56): 最適なShift = -0.0015, 最大相関 = 0.7797
# 区間 9 (Kilo: 244.55-244.57): 最適なShift = 0.0033, 最大相関 = 0.8865
# 区間 10 (Kilo: 244.56-244.58): 最適なShift = 0.0019, 最大相関 = 0.9637
# 区間 11 (Kilo: 244.57-244.58): 最適なShift = 0.0036, 最大相関 = 0.7959
# 区間 12 (Kilo: 244.58-244.60): 最適なShift = 0.0019, 最大相関 = 0.9527
# 区間 13 (Kilo: 244.59-244.60): 最適なShift = -0.0027, 最大相関 = 0.8832
# 区間 14 (Kilo: 244.60-244.61): 最適なShift = 0.0020, 最大相関 = 0.9465
# 区間 15 (Kilo: 244.61-244.62): 最適なShift = 0.0020, 最大相関 = 0.8522
# 区間 16 (Kilo: 244.61-244.63): 最適なShift = 0.0003, 最大相関 = 0.8959
# 区間 17 (Kilo: 244.62-244.64): 最適なShift = 0.0020, 最大相関 = 0.9795
# 区間 18 (Kilo: 244.63-244.64): 最適なShift = -0.0003, 最大相関 = 0.9923
# 区間 19 (Kilo: 244.64-244.65): 最適なShift = 0.0008, 最大相関 = 0.9337
# 区間 20 (Kilo: 244.65-244.66): 最適なShift = -0.0004, 最大相関 = 0.9781
# 区間 21 (Kilo: 244.65-244.67): 最適なShift = 0.0000, 最大相関 = 0.9844
# 区間 22 (Kilo: 244.67-244.68): 最適なShift = 0.0004, 最大相関 = 0.9881
# 区間 23 (Kilo: 244.68-244.69): 最適なShift = -0.0008, 最大相関 = 0.9962
# 区間 24 (Kilo: 244.68-244.70): 最適なShift = -0.0011, 最大相関 = 0.9938
# 区間 25 (Kilo: 244.69-244.71): 最適なShift = -0.0011, 最大相関 = 0.9973
# 区間 26 (Kilo: 244.70-244.72): 最適なShift = -0.0016, 最大相関 = 0.9746
# 区間 27 (Kilo: 244.71-244.73): 最適なShift = -0.0010, 最大相関 = 0.8932
# 区間 28 (Kilo: 244.71-244.74): 最適なShift = -0.0039, 最大相関 = 0.9868
# 区間 29 (Kilo: 244.72-244.75): 最適なShift = -0.0017, 最大相関 = 0.9601
# 区間 30 (Kilo: 244.74-244.76): 最適なShift = -0.0021, 最大相関 = 0.9234
# 区間 31 (Kilo: 244.74-244.76): 最適なShift = -0.0035, 最大相関 = 0.7107
# 区間 32 (Kilo: 244.75-244.77): 最適なShift = -0.0050, 最大相関 = 0.1184
# 区間 33 (Kilo: 244.76-244.77): 最適なShift = -0.0072, 最大相関 = 0.4867
# 区間 34 (Kilo: 244.76-244.78): 最適なShift = -0.0049, 最大相関 = 0.9149
# 区間 35 (Kilo: 244.77-244.79): 最適なShift = -0.0050, 最大相関 = 0.8140
# 区間 36 (Kilo: 244.78-244.80): 最適なShift = -0.0067, 最大相関 = 0.9513
# 区間 37 (Kilo: 244.79-244.81): 最適なShift = -0.0059, 最大相関 = 0.9063
# 区間 38 (Kilo: 244.80-244.82): 最適なShift = -0.0050, 最大相関 = 0.9519
# 区間 39 (Kilo: 244.81-244.84): 最適なShift = -0.0043, 最大相関 = 0.9232
# 区間 40 (Kilo: 244.82-244.85): 最適なShift = -0.0065, 最大相関 = 0.9343
# 区間 41 (Kilo: 244.83-244.85): 最適なShift = -0.0110, 最大相関 = 0.8717
# 区間 42 (Kilo: 244.84-244.86): 最適なShift = -0.0090, 最大相関 = 0.0106
# 区間 43 (Kilo: 244.84-244.87): 最適なShift = -0.0078, 最大相関 = 0.8902
# 区間 44 (Kilo: 244.85-244.88): 最適なShift = -0.0043, 最大相関 = 0.9017
# 区間 45 (Kilo: 244.86-244.89): 最適なShift = -0.0058, 最大相関 = 0.9713
# 区間 46 (Kilo: 244.88-244.91): 最適なShift = -0.0044, 最大相関 = 0.7787
# 区間 47 (Kilo: 244.88-244.92): 最適なShift = -0.0075, 最大相関 = 0.8260
# 区間 48 (Kilo: 244.90-244.93): 最適なShift = -0.0053, 最大相関 = 0.9112
# 区間 49 (Kilo: 244.91-244.94): 最適なShift = -0.0068, 最大相関 = 0.6943
# 区間 50 (Kilo: 244.92-244.95): 最適なShift = -0.0061, 最大相関 = 0.9695
# 区間 51 (Kilo: 244.93-244.95): 最適なShift = -0.0032, 最大相関 = 0.9806
# 区間 52 (Kilo: 244.94-244.96): 最適なShift = 0.0030, 最大相関 = 0.5958
# 区間 53 (Kilo: 244.95-244.96): 最適なShift = 0.0045, 最大相関 = -0.6641
# 区間 54 (Kilo: 244.96-244.97): 最適なShift = -0.0011, 最大相関 = -0.1171
# 区間 55 (Kilo: 244.96-244.98): 最適なShift = -0.0045, 最大相関 = 0.8387
# 区間 56 (Kilo: 244.96-244.98): 最適なShift = -0.0030, 最大相関 = 0.4047
#   data6を処理中...
# 分析範囲で検出された極値の数: 71
# 区間 1 (Kilo: 244.49-244.50): 最適なShift = 0.0045, 最大相関 = 0.5824
# 区間 2 (Kilo: 244.50-244.51): 最適なShift = 0.0022, 最大相関 = 0.8604
# 区間 3 (Kilo: 244.50-244.51): 最適なShift = -0.0006, 最大相関 = 0.6482
# 区間 4 (Kilo: 244.50-244.52): 最適なShift = -0.0002, 最大相関 = 0.9593
# 区間 5 (Kilo: 244.51-244.52): 最適なShift = 0.0011, 最大相関 = 0.9680
# 区間 6 (Kilo: 244.52-244.53): 最適なShift = 0.0075, 最大相関 = 0.7383
# 区間 7 (Kilo: 244.53-244.54): 最適なShift = 0.0032, 最大相関 = 0.9867
# 区間 8 (Kilo: 244.54-244.55): 最適なShift = 0.0012, 最大相関 = 0.9724
# 区間 9 (Kilo: 244.54-244.55): 最適なShift = 0.0017, 最大相関 = 0.9961
# 区間 10 (Kilo: 244.55-244.56): 最適なShift = 0.0040, 最大相関 = 0.0179
# 区間 11 (Kilo: 244.55-244.56): 最適なShift = -0.0008, 最大相関 = 0.9575
# 区間 12 (Kilo: 244.55-244.57): 最適なShift = -0.0009, 最大相関 = 0.9685
# 区間 13 (Kilo: 244.56-244.58): 最適なShift = -0.0040, 最大相関 = 0.8804
# 区間 14 (Kilo: 244.57-244.58): 最適なShift = 0.0014, 最大相関 = 0.9790
# 区間 15 (Kilo: 244.58-244.59): 最適なShift = 0.0023, 最大相関 = 0.9640
# 区間 16 (Kilo: 244.59-244.59): 最適なShift = 0.0022, 最大相関 = 0.9515
# 区間 17 (Kilo: 244.59-244.60): 最適なShift = -0.0006, 最大相関 = 0.8371
# 区間 18 (Kilo: 244.59-244.60): 最適なShift = 0.0023, 最大相関 = 0.8082
# 区間 19 (Kilo: 244.60-244.61): 最適なShift = 0.0028, 最大相関 = 0.8389
# 区間 20 (Kilo: 244.61-244.62): 最適なShift = -0.0000, 最大相関 = 0.3446
# 区間 21 (Kilo: 244.61-244.63): 最適なShift = -0.0031, 最大相関 = 0.9269
# 区間 22 (Kilo: 244.62-244.64): 最適なShift = -0.0016, 最大相関 = 0.7817
# 区間 23 (Kilo: 244.62-244.65): 最適なShift = -0.0025, 最大相関 = 0.8800
# 区間 24 (Kilo: 244.64-244.66): 最適なShift = -0.0023, 最大相関 = 0.8070
# 区間 25 (Kilo: 244.64-244.67): 最適なShift = -0.0032, 最大相関 = 0.8843
# 区間 26 (Kilo: 244.65-244.68): 最適なShift = -0.0035, 最大相関 = 0.9416
# 区間 27 (Kilo: 244.66-244.69): 最適なShift = -0.0045, 最大相関 = 0.8544
# 区間 28 (Kilo: 244.67-244.70): 最適なShift = -0.0054, 最大相関 = 0.8339
# 区間 29 (Kilo: 244.68-244.71): 最適なShift = -0.0072, 最大相関 = 0.8963
# 区間 30 (Kilo: 244.69-244.71): 最適なShift = -0.0054, 最大相関 = 0.8924
# 区間 31 (Kilo: 244.70-244.72): 最適なShift = -0.0035, 最大相関 = 0.9232
# 区間 32 (Kilo: 244.71-244.73): 最適なShift = -0.0022, 最大相関 = 0.8996
# 区間 33 (Kilo: 244.72-244.74): 最適なShift = -0.0051, 最大相関 = 0.9410
# 区間 34 (Kilo: 244.72-244.75): 最適なShift = -0.0056, 最大相関 = 0.9018
# 区間 35 (Kilo: 244.73-244.76): 最適なShift = -0.0038, 最大相関 = 0.8997
# 区間 36 (Kilo: 244.74-244.76): 最適なShift = -0.0048, 最大相関 = 0.9441
# 区間 37 (Kilo: 244.75-244.77): 最適なShift = -0.0050, 最大相関 = 0.3099
# 区間 38 (Kilo: 244.76-244.77): 最適なShift = -0.0069, 最大相関 = 0.5541
# 区間 39 (Kilo: 244.76-244.78): 最適なShift = -0.0056, 最大相関 = 0.8899
# 区間 40 (Kilo: 244.77-244.79): 最適なShift = -0.0051, 最大相関 = 0.9096
# 区間 41 (Kilo: 244.78-244.80): 最適なShift = -0.0057, 最大相関 = 0.9276
# 区間 42 (Kilo: 244.79-244.81): 最適なShift = -0.0061, 最大相関 = 0.8441
# 区間 43 (Kilo: 244.80-244.83): 最適なShift = -0.0054, 最大相関 = 0.9220
# 区間 44 (Kilo: 244.81-244.84): 最適なShift = -0.0068, 最大相関 = 0.9165
# 区間 45 (Kilo: 244.82-244.84): 最適なShift = -0.0061, 最大相関 = 0.8904
# 区間 46 (Kilo: 244.83-244.85): 最適なShift = -0.0070, 最大相関 = 0.7319
# 区間 47 (Kilo: 244.84-244.86): 最適なShift = -0.0093, 最大相関 = 0.2887
# 区間 48 (Kilo: 244.84-244.86): 最適なShift = -0.0077, 最大相関 = 0.9559
# 区間 49 (Kilo: 244.85-244.88): 最適なShift = -0.0047, 最大相関 = 0.9458
# 区間 50 (Kilo: 244.86-244.88): 最適なShift = -0.0054, 最大相関 = 0.9875
# 区間 51 (Kilo: 244.87-244.88): 最適なShift = 0.0030, 最大相関 = -0.5297
# 区間 52 (Kilo: 244.88-244.89): 最適なShift = -0.0008, 最大相関 = 0.5643
# 区間 53 (Kilo: 244.88-244.90): 最適なShift = -0.0058, 最大相関 = 0.6110
# 区間 54 (Kilo: 244.88-244.90): 最適なShift = 0.0030, 最大相関 = 0.7715
# 区間 55 (Kilo: 244.90-244.91): 最適なShift = -0.0007, 最大相関 = -0.5799
# 区間 56 (Kilo: 244.90-244.92): 最適なShift = -0.0073, 最大相関 = 0.7494
# 区間 57 (Kilo: 244.90-244.92): 最適なShift = -0.0042, 最大相関 = 0.9394
# 区間 58 (Kilo: 244.91-244.93): 最適なShift = -0.0030, 最大相関 = 0.9989
# 区間 59 (Kilo: 244.92-244.93): 最適なShift = -0.0030, 最大相関 = -0.8946
# 区間 60 (Kilo: 244.92-244.94): 最適なShift = -0.0060, 最大相関 = 0.7902
# 区間 61 (Kilo: 244.92-244.95): 最適なShift = -0.0052, 最大相関 = 0.9853
# 区間 62 (Kilo: 244.93-244.95): 最適なShift = -0.0018, 最大相関 = 0.9840
# 区間 63 (Kilo: 244.95-244.96): 最適なShift = 0.0022, 最大相関 = 0.9394
# 区間 64 (Kilo: 244.96-244.96): 最適なShift = 0.0037, 最大相関 = -0.4906
# 区間 65 (Kilo: 244.96-244.97): 最適なShift = -0.0009, 最大相関 = 0.6564
# 区間 66 (Kilo: 244.96-244.97): 最適なShift = -0.0008, 最大相関 = 0.9765
# 区間 67 (Kilo: 244.97-244.97): 最適なShift = -0.0013, 最大相関 = -0.8789
# 区間 68 (Kilo: 244.97-244.98): 最適なShift = -0.0040, 最大相関 = 0.3630
# 区間 69 (Kilo: 244.97-244.98): 最適なShift = -0.0039, 最大相関 = 0.8586
#   data7を処理中...
# 分析範囲で検出された極値の数: 70
# 区間 1 (Kilo: 244.49-244.50): 最適なShift = 0.0022, 最大相関 = 0.8954
# 区間 2 (Kilo: 244.50-244.51): 最適なShift = 0.0052, 最大相関 = -0.7090
# 区間 3 (Kilo: 244.50-244.51): 最適なShift = -0.0013, 最大相関 = -0.1710
# 区間 4 (Kilo: 244.50-244.52): 最適なShift = -0.0047, 最大相関 = 0.6498
# 区間 5 (Kilo: 244.51-244.53): 最適なShift = 0.0011, 最大相関 = 0.7088
# 区間 6 (Kilo: 244.52-244.53): 最適なShift = -0.0044, 最大相関 = 0.9921
# 区間 7 (Kilo: 244.52-244.53): 最適なShift = -0.0024, 最大相関 = -0.5922
# 区間 8 (Kilo: 244.53-244.54): 最適なShift = -0.0050, 最大相関 = 0.3168
# 区間 9 (Kilo: 244.53-244.54): 最適なShift = -0.0030, 最大相関 = 0.8105
# 区間 10 (Kilo: 244.54-244.55): 最適なShift = -0.0009, 最大相関 = 0.9137
# 区間 11 (Kilo: 244.54-244.56): 最適なShift = -0.0018, 最大相関 = 0.8265
# 区間 12 (Kilo: 244.55-244.56): 最適なShift = -0.0030, 最大相関 = -0.5423
# 区間 13 (Kilo: 244.55-244.57): 最適なShift = -0.0060, 最大相関 = 0.2290
# 区間 14 (Kilo: 244.55-244.57): 最適なShift = -0.0067, 最大相関 = 0.7383
# 区間 15 (Kilo: 244.56-244.58): 最適なShift = -0.0018, 最大相関 = 0.9174
# 区間 16 (Kilo: 244.57-244.59): 最適なShift = -0.0015, 最大相関 = 0.8858
# 区間 17 (Kilo: 244.58-244.60): 最適なShift = -0.0039, 最大相関 = 0.8064
# 区間 18 (Kilo: 244.59-244.61): 最適なShift = -0.0071, 最大相関 = 0.8841
# 区間 19 (Kilo: 244.59-244.61): 最適なShift = 0.0004, 最大相関 = 0.9420
# 区間 20 (Kilo: 244.61-244.62): 最適なShift = -0.0006, 最大相関 = 0.9892
# 区間 21 (Kilo: 244.61-244.62): 最適なShift = -0.0019, 最大相関 = 0.8552
# 区間 22 (Kilo: 244.62-244.63): 最適なShift = 0.0017, 最大相関 = 0.4261
# 区間 23 (Kilo: 244.63-244.64): 最適なShift = -0.0014, 最大相関 = 0.0158
# 区間 24 (Kilo: 244.63-244.64): 最適なShift = -0.0040, 最大相関 = 0.4108
# 区間 25 (Kilo: 244.63-244.65): 最適なShift = -0.0044, 最大相関 = 0.4146
# 区間 26 (Kilo: 244.64-244.66): 最適なShift = -0.0068, 最大相関 = 0.7910
# 区間 27 (Kilo: 244.65-244.67): 最適なShift = -0.0055, 最大相関 = 0.8628
# 区間 28 (Kilo: 244.65-244.68): 最適なShift = -0.0055, 最大相関 = 0.7830
# 区間 29 (Kilo: 244.66-244.69): 最適なShift = -0.0050, 最大相関 = 0.9168
# 区間 30 (Kilo: 244.68-244.70): 最適なShift = -0.0045, 最大相関 = 0.8651
# 区間 31 (Kilo: 244.68-244.70): 最適なShift = -0.0050, 最大相関 = 0.9513
# 区間 32 (Kilo: 244.69-244.71): 最適なShift = -0.0044, 最大相関 = 0.8519
# 区間 33 (Kilo: 244.70-244.72): 最適なShift = -0.0055, 最大相関 = 0.9387
# 区間 34 (Kilo: 244.71-244.73): 最適なShift = -0.0032, 最大相関 = 0.9423
# 区間 35 (Kilo: 244.72-244.73): 最適なShift = 0.0006, 最大相関 = 0.9976
# 区間 36 (Kilo: 244.73-244.73): 最適なShift = 0.0037, 最大相関 = -0.6295
# 区間 37 (Kilo: 244.73-244.74): 最適なShift = -0.0009, 最大相関 = -0.0603
# 区間 38 (Kilo: 244.73-244.75): 最適なShift = -0.0074, 最大相関 = 0.5335
# 区間 39 (Kilo: 244.73-244.76): 最適なShift = -0.0062, 最大相関 = 0.7961
# 区間 40 (Kilo: 244.74-244.76): 最適なShift = -0.0062, 最大相関 = 0.9544
# 区間 41 (Kilo: 244.75-244.77): 最適なShift = -0.0050, 最大相関 = -0.6204
# 区間 42 (Kilo: 244.76-244.78): 最適なShift = -0.0082, 最大相関 = 0.1262
# 区間 43 (Kilo: 244.76-244.79): 最適なShift = -0.0077, 最大相関 = 0.6181
# 区間 44 (Kilo: 244.77-244.80): 最適なShift = -0.0086, 最大相関 = 0.7631
# 区間 45 (Kilo: 244.78-244.81): 最適なShift = -0.0091, 最大相関 = 0.7218
# 区間 46 (Kilo: 244.79-244.82): 最適なShift = -0.0110, 最大相関 = 0.4053
# 区間 47 (Kilo: 244.80-244.83): 最適なShift = -0.0088, 最大相関 = 0.9373
# 区間 48 (Kilo: 244.81-244.84): 最適なShift = -0.0075, 最大相関 = 0.8766
# 区間 49 (Kilo: 244.82-244.84): 最適なShift = -0.0082, 最大相関 = 0.8981
# 区間 50 (Kilo: 244.83-244.85): 最適なShift = -0.0066, 最大相関 = 0.5950
# 区間 51 (Kilo: 244.84-244.86): 最適なShift = -0.0080, 最大相関 = -0.1330
# 区間 52 (Kilo: 244.84-244.87): 最適なShift = -0.0114, 最大相関 = 0.6215
# 区間 53 (Kilo: 244.85-244.88): 最適なShift = -0.0077, 最大相関 = 0.9571
# 区間 54 (Kilo: 244.86-244.89): 最適なShift = -0.0043, 最大相関 = 0.9236
# 区間 55 (Kilo: 244.88-244.90): 最適なShift = 0.0031, 最大相関 = 0.8673
# 区間 56 (Kilo: 244.89-244.90): 最適なShift = 0.0022, 最大相関 = 0.9519
# 区間 57 (Kilo: 244.90-244.91): 最適なShift = 0.0022, 最大相関 = 0.5005
# 区間 58 (Kilo: 244.91-244.92): 最適なShift = -0.0006, 最大相関 = 0.2532
# 区間 59 (Kilo: 244.91-244.93): 最適なShift = -0.0060, 最大相関 = 0.9303
# 区間 60 (Kilo: 244.91-244.93): 最適なShift = -0.0038, 最大相関 = 0.9635
# 区間 61 (Kilo: 244.92-244.94): 最適なShift = -0.0011, 最大相関 = 0.9695
# 区間 62 (Kilo: 244.93-244.94): 最適なShift = 0.0022, 最大相関 = 0.8616
# 区間 63 (Kilo: 244.94-244.95): 最適なShift = -0.0006, 最大相関 = 0.2981
# 区間 64 (Kilo: 244.94-244.96): 最適なShift = -0.0049, 最大相関 = 0.9023
# 区間 65 (Kilo: 244.94-244.97): 最適なShift = -0.0022, 最大相関 = 0.9870
# 区間 66 (Kilo: 244.96-244.97): 最適なShift = -0.0004, 最大相関 = 0.9873
# 区間 67 (Kilo: 244.97-244.98): 最適なShift = 0.0033, 最大相関 = 0.8876
# 区間 68 (Kilo: 244.98-244.98): 最適なShift = 0.0035, 最大相関 = 0.9358
#   data8を処理中...
# 分析範囲で検出された極値の数: 67
# 区間 1 (Kilo: 244.49-244.50): 最適なShift = 0.0052, 最大相関 = 0.3736
# 区間 2 (Kilo: 244.50-244.51): 最適なShift = 0.0067, 最大相関 = 0.3726
# 区間 3 (Kilo: 244.51-244.52): 最適なShift = 0.0052, 最大相関 = 0.0395
# 区間 4 (Kilo: 244.52-244.53): 最適なShift = 0.0060, 最大相関 = 0.6281
# 区間 5 (Kilo: 244.52-244.54): 最適なShift = 0.0010, 最大相関 = -0.0494
# 区間 6 (Kilo: 244.53-244.55): 最適なShift = 0.0075, 最大相関 = 0.5016
# 区間 7 (Kilo: 244.54-244.56): 最適なShift = 0.0013, 最大相関 = 0.8156
# 区間 8 (Kilo: 244.55-244.56): 最適なShift = 0.0052, 最大相関 = -0.1005
# 区間 9 (Kilo: 244.56-244.57): 最適なShift = 0.0037, 最大相関 = 0.1962
# 区間 10 (Kilo: 244.57-244.57): 最適なShift = -0.0009, 最大相関 = -0.2417
# 区間 11 (Kilo: 244.57-244.58): 最適なShift = -0.0041, 最大相関 = 0.3576
# 区間 12 (Kilo: 244.57-244.58): 最適なShift = 0.0022, 最大相関 = 0.9209
# 区間 13 (Kilo: 244.58-244.59): 最適なShift = 0.0037, 最大相関 = -0.2891
# 区間 14 (Kilo: 244.58-244.59): 最適なShift = -0.0009, 最大相関 = -0.2487
# 区間 15 (Kilo: 244.58-244.60): 最適なShift = -0.0044, 最大相関 = 0.2235
# 区間 16 (Kilo: 244.59-244.61): 最適なShift = -0.0101, 最大相関 = 0.6779
# 区間 17 (Kilo: 244.59-244.62): 最適なShift = -0.0049, 最大相関 = 0.8476
# 区間 18 (Kilo: 244.61-244.62): 最適なShift = -0.0050, 最大相関 = 0.6181
# 区間 19 (Kilo: 244.61-244.63): 最適なShift = -0.0080, 最大相関 = 0.7866
# 区間 20 (Kilo: 244.62-244.63): 最適なShift = -0.0044, 最大相関 = 0.7707
# 区間 21 (Kilo: 244.62-244.64): 最適なShift = -0.0063, 最大相関 = -0.7245
# 区間 22 (Kilo: 244.63-244.64): 最適なShift = -0.0080, 最大相関 = -0.2656
# 区間 23 (Kilo: 244.63-244.65): 最適なShift = -0.0071, 最大相関 = 0.4721
# 区間 24 (Kilo: 244.64-244.66): 最適なShift = -0.0090, 最大相関 = 0.5650
# 区間 25 (Kilo: 244.64-244.67): 最適なShift = -0.0066, 最大相関 = 0.4883
# 区間 26 (Kilo: 244.65-244.68): 最適なShift = -0.0093, 最大相関 = 0.4468
# 区間 27 (Kilo: 244.66-244.69): 最適なShift = -0.0080, 最大相関 = 0.7576
# 区間 28 (Kilo: 244.68-244.70): 最適なShift = -0.0072, 最大相関 = 0.7297
# 区間 29 (Kilo: 244.68-244.71): 最適なShift = -0.0083, 最大相関 = 0.8114
# 区間 30 (Kilo: 244.69-244.71): 最適なShift = -0.0064, 最大相関 = 0.7656
# 区間 31 (Kilo: 244.70-244.72): 最適なShift = -0.0065, 最大相関 = 0.8433
# 区間 32 (Kilo: 244.71-244.73): 最適なShift = -0.0059, 最大相関 = 0.5485
# 区間 33 (Kilo: 244.71-244.74): 最適なShift = -0.0080, 最大相関 = 0.8860
# 区間 34 (Kilo: 244.72-244.75): 最適なShift = -0.0065, 最大相関 = 0.8209
# 区間 35 (Kilo: 244.73-244.76): 最適なShift = -0.0055, 最大相関 = 0.8311
# 区間 36 (Kilo: 244.74-244.76): 最適なShift = -0.0059, 最大相関 = 0.8342
# 区間 37 (Kilo: 244.75-244.77): 最適なShift = -0.0060, 最大相関 = 0.1568
# 区間 38 (Kilo: 244.76-244.78): 最適なShift = -0.0083, 最大相関 = 0.2534
# 区間 39 (Kilo: 244.76-244.78): 最適なShift = -0.0064, 最大相関 = 0.7925
# 区間 40 (Kilo: 244.77-244.79): 最適なShift = -0.0063, 最大相関 = 0.8882
# 区間 41 (Kilo: 244.78-244.80): 最適なShift = -0.0067, 最大相関 = 0.9034
# 区間 42 (Kilo: 244.79-244.82): 最適なShift = -0.0071, 最大相関 = 0.6037
# 区間 43 (Kilo: 244.79-244.83): 最適なShift = -0.0065, 最大相関 = 0.9643
# 区間 44 (Kilo: 244.81-244.84): 最適なShift = -0.0051, 最大相関 = 0.9525
# 区間 45 (Kilo: 244.82-244.84): 最適なShift = -0.0042, 最大相関 = 0.9240
# 区間 46 (Kilo: 244.83-244.85): 最適なShift = -0.0060, 最大相関 = 0.4511
# 区間 47 (Kilo: 244.84-244.86): 最適なShift = -0.0095, 最大相関 = 0.1005
# 区間 48 (Kilo: 244.84-244.87): 最適なShift = -0.0092, 最大相関 = 0.7628
# 区間 49 (Kilo: 244.85-244.88): 最適なShift = -0.0059, 最大相関 = 0.9383
# 区間 50 (Kilo: 244.86-244.89): 最適なShift = -0.0040, 最大相関 = 0.9800
# 区間 51 (Kilo: 244.87-244.90): 最適なShift = 0.0005, 最大相関 = 0.8961
# 区間 52 (Kilo: 244.89-244.90): 最適なShift = 0.0030, 最大相関 = 0.8584
# 区間 53 (Kilo: 244.90-244.91): 最適なShift = 0.0022, 最大相関 = 0.1056
# 区間 54 (Kilo: 244.91-244.91): 最適なShift = -0.0006, 最大相関 = 0.8769
# 区間 55 (Kilo: 244.91-244.92): 最適なShift = -0.0030, 最大相関 = 0.9817
# 区間 56 (Kilo: 244.91-244.93): 最適なShift = 0.0021, 最大相関 = 0.9519
# 区間 57 (Kilo: 244.92-244.93): 最適なShift = 0.0037, 最大相関 = 0.0706
# 区間 58 (Kilo: 244.93-244.94): 最適なShift = 0.0052, 最大相関 = -0.5475
# 区間 59 (Kilo: 244.94-244.95): 最適なShift = -0.0013, 最大相関 = 0.4432
# 区間 60 (Kilo: 244.94-244.96): 最適なShift = -0.0055, 最大相関 = 0.6413
# 区間 61 (Kilo: 244.94-244.97): 最適なShift = -0.0033, 最大相関 = 0.9840
# 区間 62 (Kilo: 244.96-244.97): 最適なShift = -0.0018, 最大相関 = 0.9961
# 区間 63 (Kilo: 244.97-244.97): 最適なShift = 0.0007, 最大相関 = 0.6558
# 区間 64 (Kilo: 244.97-244.98): 最適なShift = -0.0002, 最大相関 = -0.0342
# 区間 65 (Kilo: 244.97-244.98): 最適なShift = -0.0030, 最大相関 = 0.4800
#   data9を処理中...
# 分析範囲で検出された極値の数: 63
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = 0.0019, 最大相関 = 0.9467
# 区間 2 (Kilo: 244.50-244.52): 最適なShift = 0.0019, 最大相関 = 0.9594
# 区間 3 (Kilo: 244.51-244.52): 最適なShift = 0.0047, 最大相関 = 0.9659
# 区間 4 (Kilo: 244.52-244.53): 最適なShift = 0.0019, 最大相関 = 0.9774
# 区間 5 (Kilo: 244.52-244.53): 最適なShift = 0.0037, 最大相関 = 0.3307
# 区間 6 (Kilo: 244.53-244.54): 最適なShift = -0.0000, 最大相関 = 0.1545
# 区間 7 (Kilo: 244.53-244.55): 最適なShift = -0.0052, 最大相関 = 0.4952
# 区間 8 (Kilo: 244.54-244.55): 最適なShift = -0.0043, 最大相関 = 0.3456
# 区間 9 (Kilo: 244.54-244.56): 最適なShift = -0.0062, 最大相関 = 0.8551
# 区間 10 (Kilo: 244.55-244.57): 最適なShift = 0.0008, 最大相関 = 0.8525
# 区間 11 (Kilo: 244.56-244.58): 最適なShift = 0.0005, 最大相関 = 0.9325
# 区間 12 (Kilo: 244.57-244.59): 最適なShift = -0.0022, 最大相関 = 0.9827
# 区間 13 (Kilo: 244.58-244.60): 最適なShift = -0.0012, 最大相関 = 0.9021
# 区間 14 (Kilo: 244.59-244.61): 最適なShift = -0.0052, 最大相関 = 0.7455
# 区間 15 (Kilo: 244.59-244.61): 最適なShift = 0.0025, 最大相関 = 0.8883
# 区間 16 (Kilo: 244.61-244.62): 最適なShift = 0.0031, 最大相関 = 0.5427
# 区間 17 (Kilo: 244.61-244.62): 最適なShift = 0.0000, 最大相関 = 0.8230
# 区間 18 (Kilo: 244.62-244.63): 最適なShift = 0.0015, 最大相関 = 0.9884
# 区間 19 (Kilo: 244.62-244.63): 最適なShift = 0.0036, 最大相関 = 0.9579
# 区間 20 (Kilo: 244.63-244.64): 最適なShift = -0.0005, 最大相関 = 0.9294
# 区間 21 (Kilo: 244.63-244.65): 最適なShift = -0.0020, 最大相関 = 0.7728
# 区間 22 (Kilo: 244.64-244.66): 最適なShift = -0.0046, 最大相関 = 0.8642
# 区間 23 (Kilo: 244.65-244.67): 最適なShift = -0.0042, 最大相関 = 0.9174
# 区間 24 (Kilo: 244.65-244.68): 最適なShift = -0.0042, 最大相関 = 0.8669
# 区間 25 (Kilo: 244.66-244.69): 最適なShift = -0.0044, 最大相関 = 0.9297
# 区間 26 (Kilo: 244.67-244.70): 最適なShift = -0.0042, 最大相関 = 0.8438
# 区間 27 (Kilo: 244.68-244.70): 最適なShift = -0.0053, 最大相関 = 0.9323
# 区間 28 (Kilo: 244.69-244.71): 最適なShift = -0.0042, 最大相関 = 0.8934
# 区間 29 (Kilo: 244.70-244.72): 最適なShift = -0.0041, 最大相関 = 0.9795
# 区間 30 (Kilo: 244.71-244.73): 最適なShift = -0.0030, 最大相関 = 0.4781
# 区間 31 (Kilo: 244.72-244.74): 最適なShift = -0.0071, 最大相関 = 0.9374
# 区間 32 (Kilo: 244.72-244.75): 最適なShift = -0.0037, 最大相関 = 0.9389
# 区間 33 (Kilo: 244.74-244.76): 最適なShift = -0.0035, 最大相関 = 0.9183
# 区間 34 (Kilo: 244.74-244.76): 最適なShift = -0.0032, 最大相関 = 0.6792
# 区間 35 (Kilo: 244.75-244.77): 最適なShift = -0.0053, 最大相関 = -0.0550
# 区間 36 (Kilo: 244.76-244.77): 最適なShift = -0.0075, 最大相関 = 0.2706
# 区間 37 (Kilo: 244.76-244.79): 最適なShift = -0.0062, 最大相関 = 0.7156
# 区間 38 (Kilo: 244.77-244.79): 最適なShift = -0.0069, 最大相関 = 0.8536
# 区間 39 (Kilo: 244.78-244.81): 最適なShift = -0.0064, 最大相関 = 0.7807
# 区間 40 (Kilo: 244.79-244.82): 最適なShift = -0.0089, 最大相関 = 0.7798
# 区間 41 (Kilo: 244.80-244.83): 最適なShift = -0.0061, 最大相関 = 0.8753
# 区間 42 (Kilo: 244.81-244.84): 最適なShift = -0.0082, 最大相関 = 0.8637
# 区間 43 (Kilo: 244.82-244.85): 最適なShift = -0.0077, 最大相関 = 0.7919
# 区間 44 (Kilo: 244.83-244.85): 最適なShift = -0.0080, 最大相関 = 0.5210
# 区間 45 (Kilo: 244.84-244.86): 最適なShift = -0.0119, 最大相関 = -0.0621
# 区間 46 (Kilo: 244.84-244.87): 最適なShift = -0.0110, 最大相関 = 0.6035
# 区間 47 (Kilo: 244.85-244.88): 最適なShift = -0.0093, 最大相関 = 0.8303
# 区間 48 (Kilo: 244.86-244.89): 最適なShift = -0.0090, 最大相関 = 0.9350
# 区間 49 (Kilo: 244.87-244.90): 最適なShift = -0.0053, 最大相関 = 0.9693
# 区間 50 (Kilo: 244.89-244.90): 最適なShift = 0.0015, 最大相関 = 0.9818
# 区間 51 (Kilo: 244.90-244.91): 最適なShift = 0.0030, 最大相関 = -0.7559
# 区間 52 (Kilo: 244.91-244.92): 最適なShift = -0.0008, 最大相関 = 0.7131
# 区間 53 (Kilo: 244.91-244.93): 最適なShift = -0.0042, 最大相関 = 0.9165
# 区間 54 (Kilo: 244.91-244.94): 最適なShift = -0.0049, 最大相関 = 0.8271
# 区間 55 (Kilo: 244.92-244.95): 最適なShift = -0.0049, 最大相関 = 0.9815
# 区間 56 (Kilo: 244.93-244.96): 最適なShift = -0.0041, 最大相関 = 0.9540
# 区間 57 (Kilo: 244.94-244.97): 最適なShift = -0.0014, 最大相関 = 0.9625
# 区間 58 (Kilo: 244.96-244.97): 最適なShift = 0.0015, 最大相関 = 0.9198
# 区間 59 (Kilo: 244.97-244.98): 最適なShift = -0.0008, 最大相関 = 0.7940
# 区間 60 (Kilo: 244.97-244.98): 最適なShift = -0.0012, 最大相関 = 0.8332
# 区間 61 (Kilo: 244.98-244.99): 最適なShift = 0.0022, 最大相関 = -0.3775
#   data10を処理中...
# 分析範囲で検出された極値の数: 64
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = 0.0052, 最大相関 = -0.2689
# 区間 2 (Kilo: 244.50-244.51): 最適なShift = 0.0052, 最大相関 = -0.3297
# 区間 3 (Kilo: 244.51-244.52): 最適なShift = -0.0013, 最大相関 = 0.0849
# 区間 4 (Kilo: 244.51-244.52): 最適なShift = 0.0003, 最大相関 = 0.9981
# 区間 5 (Kilo: 244.52-244.53): 最適なShift = 0.0012, 最大相関 = 0.3292
# 区間 6 (Kilo: 244.52-244.53): 最適なShift = -0.0019, 最大相関 = 0.9274
# 区間 7 (Kilo: 244.53-244.54): 最適なShift = -0.0022, 最大相関 = 0.9752
# 区間 8 (Kilo: 244.53-244.55): 最適なShift = -0.0024, 最大相関 = 0.6230
# 区間 9 (Kilo: 244.54-244.56): 最適なShift = -0.0046, 最大相関 = 0.6181
# 区間 10 (Kilo: 244.54-244.57): 最適なShift = -0.0079, 最大相関 = 0.7530
# 区間 11 (Kilo: 244.55-244.58): 最適なShift = -0.0058, 最大相関 = 0.3457
# 区間 12 (Kilo: 244.56-244.59): 最適なShift = -0.0102, 最大相関 = 0.6260
# 区間 13 (Kilo: 244.57-244.60): 最適なShift = -0.0068, 最大相関 = 0.5164
# 区間 14 (Kilo: 244.58-244.60): 最適なShift = -0.0102, 最大相関 = 0.6454
# 区間 15 (Kilo: 244.59-244.61): 最適なShift = -0.0116, 最大相関 = 0.5466
# 区間 16 (Kilo: 244.59-244.62): 最適なShift = -0.0038, 最大相関 = 0.6823
# 区間 17 (Kilo: 244.61-244.62): 最適なShift = -0.0041, 最大相関 = -0.0198
# 区間 18 (Kilo: 244.61-244.63): 最適なShift = -0.0071, 最大相関 = 0.8140
# 区間 19 (Kilo: 244.62-244.64): 最適なShift = -0.0050, 最大相関 = 0.0501
# 区間 20 (Kilo: 244.62-244.65): 最適なShift = -0.0061, 最大相関 = 0.4035
# 区間 21 (Kilo: 244.64-244.66): 最適なShift = -0.0086, 最大相関 = 0.5650
# 区間 22 (Kilo: 244.64-244.67): 最適なShift = -0.0064, 最大相関 = 0.8903
# 区間 23 (Kilo: 244.65-244.68): 最適なShift = -0.0065, 最大相関 = 0.7517
# 区間 24 (Kilo: 244.66-244.69): 最適なShift = -0.0058, 最大相関 = 0.8891
# 区間 25 (Kilo: 244.68-244.70): 最適なShift = -0.0055, 最大相関 = 0.7900
# 区間 26 (Kilo: 244.68-244.71): 最適なShift = -0.0067, 最大相関 = 0.8457
# 区間 27 (Kilo: 244.69-244.71): 最適なShift = -0.0059, 最大相関 = 0.7771
# 区間 28 (Kilo: 244.70-244.72): 最適なShift = -0.0066, 最大相関 = 0.8636
# 区間 29 (Kilo: 244.71-244.72): 最適なShift = -0.0063, 最大相関 = 0.7245
# 区間 30 (Kilo: 244.71-244.73): 最適なShift = 0.0020, 最大相関 = 0.6958
# 区間 31 (Kilo: 244.73-244.73): 最適なShift = 0.0045, 最大相関 = -0.5817
# 区間 32 (Kilo: 244.73-244.74): 最適なShift = -0.0011, 最大相関 = -0.0533
# 区間 33 (Kilo: 244.73-244.75): 最適なShift = -0.0061, 最大相関 = 0.6711
# 区間 34 (Kilo: 244.73-244.76): 最適なShift = -0.0034, 最大相関 = 0.9286
# 区間 35 (Kilo: 244.74-244.76): 最適なShift = -0.0038, 最大相関 = 0.8946
# 区間 36 (Kilo: 244.75-244.77): 最適なShift = -0.0050, 最大相関 = 0.2823
# 区間 37 (Kilo: 244.76-244.77): 最適なShift = -0.0072, 最大相関 = 0.4472
# 区間 38 (Kilo: 244.76-244.78): 最適なShift = -0.0057, 最大相関 = 0.8727
# 区間 39 (Kilo: 244.77-244.79): 最適なShift = -0.0059, 最大相関 = 0.8680
# 区間 40 (Kilo: 244.78-244.80): 最適なShift = -0.0058, 最大相関 = 0.9595
# 区間 41 (Kilo: 244.79-244.81): 最適なShift = -0.0058, 最大相関 = 0.9037
# 区間 42 (Kilo: 244.80-244.82): 最適なShift = -0.0048, 最大相関 = 0.9575
# 区間 43 (Kilo: 244.81-244.84): 最適なShift = -0.0051, 最大相関 = 0.8846
# 区間 44 (Kilo: 244.82-244.85): 最適なShift = -0.0085, 最大相関 = 0.9123
# 区間 45 (Kilo: 244.83-244.85): 最適なShift = -0.0080, 最大相関 = 0.4506
# 区間 46 (Kilo: 244.84-244.86): 最適なShift = -0.0108, 最大相関 = -0.1401
# 区間 47 (Kilo: 244.84-244.87): 最適なShift = -0.0108, 最大相関 = 0.7711
# 区間 48 (Kilo: 244.85-244.88): 最適なShift = -0.0062, 最大相関 = 0.9527
# 区間 49 (Kilo: 244.86-244.89): 最適なShift = -0.0039, 最大相関 = 0.9984
# 区間 50 (Kilo: 244.87-244.89): 最適なShift = 0.0005, 最大相関 = 0.9831
# 区間 51 (Kilo: 244.89-244.89): 最適なShift = -0.0022, 最大相関 = 0.4762
# 区間 52 (Kilo: 244.89-244.90): 最適なShift = -0.0039, 最大相関 = 0.9969
# 区間 53 (Kilo: 244.89-244.90): 最適なShift = 0.0005, 最大相関 = 0.9919
# 区間 54 (Kilo: 244.90-244.91): 最適なShift = 0.0022, 最大相関 = -0.6482
# 区間 55 (Kilo: 244.91-244.92): 最適なShift = -0.0006, 最大相関 = 0.6666
# 区間 56 (Kilo: 244.91-244.93): 最適なShift = -0.0056, 最大相関 = 0.8827
# 区間 57 (Kilo: 244.91-244.94): 最適なShift = -0.0056, 最大相関 = 0.8763
# 区間 58 (Kilo: 244.92-244.95): 最適なShift = -0.0042, 最大相関 = 0.9458
# 区間 59 (Kilo: 244.93-244.96): 最適なShift = -0.0034, 最大相関 = 0.9829
# 区間 60 (Kilo: 244.94-244.96): 最適なShift = -0.0002, 最大相関 = 0.9778
# 区間 61 (Kilo: 244.96-244.97): 最適なShift = 0.0012, 最大相関 = 0.9472
# 区間 62 (Kilo: 244.97-244.98): 最適なShift = 0.0052, 最大相関 = -0.2214
#   data11を処理中...
# 分析範囲で検出された極値の数: 68
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = 0.0075, 最大相関 = 0.7062
# 区間 2 (Kilo: 244.51-244.52): 最適なShift = 0.0067, 最大相関 = 0.7438
# 区間 3 (Kilo: 244.52-244.53): 最適なShift = 0.0037, 最大相関 = 0.5972
# 区間 4 (Kilo: 244.52-244.53): 最適なShift = -0.0006, 最大相関 = -0.5102
# 区間 5 (Kilo: 244.53-244.54): 最適なShift = -0.0048, 最大相関 = 0.2415
# 区間 6 (Kilo: 244.53-244.54): 最適なShift = -0.0045, 最大相関 = 0.1378
# 区間 7 (Kilo: 244.54-244.55): 最適なShift = -0.0001, 最大相関 = 0.9940
# 区間 8 (Kilo: 244.54-244.56): 最適なShift = 0.0000, 最大相関 = 0.1263
# 区間 9 (Kilo: 244.55-244.56): 最適なShift = 0.0052, 最大相関 = 0.1243
# 区間 10 (Kilo: 244.56-244.58): 最適なShift = 0.0105, 最大相関 = 0.7850
# 区間 11 (Kilo: 244.57-244.58): 最適なShift = 0.0043, 最大相関 = 0.9415
# 区間 12 (Kilo: 244.58-244.59): 最適なShift = 0.0039, 最大相関 = 0.8760
# 区間 13 (Kilo: 244.59-244.60): 最適なShift = 0.0067, 最大相関 = 0.4026
# 区間 14 (Kilo: 244.60-244.61): 最適なShift = 0.0045, 最大相関 = 0.3241
# 区間 15 (Kilo: 244.60-244.61): 最適なShift = 0.0037, 最大相関 = 0.6299
# 区間 16 (Kilo: 244.61-244.62): 最適なShift = 0.0052, 最大相関 = -0.0456
# 区間 17 (Kilo: 244.62-244.62): 最適なShift = 0.0037, 最大相関 = 0.6282
# 区間 18 (Kilo: 244.62-244.63): 最適なShift = 0.0037, 最大相関 = -0.3027
# 区間 19 (Kilo: 244.63-244.63): 最適なShift = 0.0045, 最大相関 = 0.9034
# 区間 20 (Kilo: 244.63-244.65): 最適なShift = 0.0026, 最大相関 = 0.7949
# 区間 21 (Kilo: 244.64-244.65): 最適なShift = 0.0009, 最大相関 = 0.9369
# 区間 22 (Kilo: 244.65-244.67): 最適なShift = -0.0003, 最大相関 = 0.8623
# 区間 23 (Kilo: 244.65-244.68): 最適なShift = -0.0024, 最大相関 = 0.9238
# 区間 24 (Kilo: 244.67-244.68): 最適なShift = -0.0010, 最大相関 = 0.9983
# 区間 25 (Kilo: 244.68-244.69): 最適なShift = -0.0005, 最大相関 = 0.9837
# 区間 26 (Kilo: 244.68-244.69): 最適なShift = 0.0022, 最大相関 = 0.6629
# 区間 27 (Kilo: 244.69-244.70): 最適なShift = -0.0006, 最大相関 = -0.5119
# 区間 28 (Kilo: 244.69-244.70): 最適なShift = -0.0049, 最大相関 = 0.5089
# 区間 29 (Kilo: 244.69-244.71): 最適なShift = -0.0024, 最大相関 = 0.9605
# 区間 30 (Kilo: 244.70-244.71): 最適なShift = -0.0004, 最大相関 = 0.9860
# 区間 31 (Kilo: 244.71-244.72): 最適なShift = 0.0022, 最大相関 = 0.9867
# 区間 32 (Kilo: 244.72-244.72): 最適なShift = 0.0022, 最大相関 = 0.7683
# 区間 33 (Kilo: 244.72-244.73): 最適なShift = -0.0006, 最大相関 = 0.2523
# 区間 34 (Kilo: 244.72-244.74): 最適なShift = -0.0049, 最大相関 = 0.9382
# 区間 35 (Kilo: 244.72-244.75): 最適なShift = -0.0030, 最大相関 = 0.9501
# 区間 36 (Kilo: 244.73-244.76): 最適なShift = -0.0027, 最大相関 = 0.8807
# 区間 37 (Kilo: 244.74-244.77): 最適なShift = -0.0074, 最大相関 = 0.8719
# 区間 38 (Kilo: 244.75-244.78): 最適なShift = 0.0006, 最大相関 = 0.8628
# 区間 39 (Kilo: 244.77-244.79): 最適なShift = -0.0024, 最大相関 = 0.9738
# 区間 40 (Kilo: 244.78-244.80): 最適なShift = -0.0018, 最大相関 = 0.9742
# 区間 41 (Kilo: 244.79-244.81): 最適なShift = -0.0021, 最大相関 = 0.9977
# 区間 42 (Kilo: 244.80-244.82): 最適なShift = -0.0009, 最大相関 = 0.9942
# 区間 43 (Kilo: 244.81-244.83): 最適なShift = -0.0011, 最大相関 = 0.9881
# 区間 44 (Kilo: 244.82-244.84): 最適なShift = -0.0026, 最大相関 = 0.9918
# 区間 45 (Kilo: 244.83-244.84): 最適なShift = -0.0016, 最大相関 = 0.9949
# 区間 46 (Kilo: 244.84-244.86): 最適なShift = -0.0017, 最大相関 = 0.6156
# 区間 47 (Kilo: 244.84-244.86): 最適なShift = -0.0041, 最大相関 = 0.9878
# 区間 48 (Kilo: 244.85-244.88): 最適なShift = -0.0020, 最大相関 = 0.9666
# 区間 49 (Kilo: 244.86-244.88): 最適なShift = -0.0007, 最大相関 = 0.9834
# 区間 50 (Kilo: 244.87-244.89): 最適なShift = 0.0027, 最大相関 = 0.9926
# 区間 51 (Kilo: 244.89-244.89): 最適なShift = 0.0023, 最大相関 = 0.9253
# 区間 52 (Kilo: 244.89-244.90): 最適なShift = 0.0010, 最大相関 = 0.9731
# 区間 53 (Kilo: 244.89-244.90): 最適なShift = 0.0015, 最大相関 = 0.9929
# 区間 54 (Kilo: 244.90-244.90): 最適なShift = -0.0004, 最大相関 = 0.8835
# 区間 55 (Kilo: 244.90-244.91): 最適なShift = 0.0015, 最大相関 = 0.9785
# 区間 56 (Kilo: 244.90-244.92): 最適なShift = 0.0037, 最大相関 = 0.8585
# 区間 57 (Kilo: 244.91-244.92): 最適なShift = 0.0015, 最大相関 = 0.9571
# 区間 58 (Kilo: 244.92-244.92): 最適なShift = -0.0004, 最大相関 = 0.8791
# 区間 59 (Kilo: 244.92-244.93): 最適なShift = 0.0005, 最大相関 = 0.9969
# 区間 60 (Kilo: 244.92-244.94): 最適なShift = 0.0000, 最大相関 = 0.9633
# 区間 61 (Kilo: 244.93-244.96): 最適なShift = 0.0038, 最大相関 = 0.9710
# 区間 62 (Kilo: 244.94-244.96): 最適なShift = 0.0012, 最大相関 = 0.9780
# 区間 63 (Kilo: 244.96-244.97): 最適なShift = 0.0023, 最大相関 = 0.9788
# 区間 64 (Kilo: 244.97-244.97): 最適なShift = 0.0052, 最大相関 = -0.2819
# 区間 65 (Kilo: 244.97-244.98): 最適なShift = 0.0045, 最大相関 = 0.1898
# 区間 66 (Kilo: 244.98-244.98): 最適なShift = 0.0015, 最大相関 = 0.6810
#   data12を処理中...
# 分析範囲で検出された極値の数: 73
# 区間 1 (Kilo: 244.49-244.51): 最適なShift = -0.0040, 最大相関 = 0.5699
# 区間 2 (Kilo: 244.50-244.52): 最適なShift = -0.0031, 最大相関 = 0.7180
# 区間 3 (Kilo: 244.51-244.53): 最適なShift = -0.0058, 最大相関 = 0.8972
# 区間 4 (Kilo: 244.52-244.54): 最適なShift = -0.0063, 最大相関 = 0.8523
# 区間 5 (Kilo: 244.52-244.54): 最適なShift = 0.0037, 最大相関 = 0.6883
# 区間 6 (Kilo: 244.54-244.55): 最適なShift = 0.0025, 最大相関 = 0.9639
# 区間 7 (Kilo: 244.54-244.55): 最適なShift = 0.0037, 最大相関 = 0.6706
# 区間 8 (Kilo: 244.55-244.56): 最適なShift = 0.0013, 最大相関 = -0.4384
# 区間 9 (Kilo: 244.55-244.56): 最適なShift = -0.0050, 最大相関 = 0.5746
# 区間 10 (Kilo: 244.55-244.57): 最適なShift = -0.0024, 最大相関 = 0.9595
# 区間 11 (Kilo: 244.56-244.57): 最適なShift = 0.0021, 最大相関 = 0.8633
# 区間 12 (Kilo: 244.57-244.58): 最適なShift = 0.0022, 最大相関 = 0.8852
# 区間 13 (Kilo: 244.58-244.58): 最適なShift = -0.0006, 最大相関 = -0.0840
# 区間 14 (Kilo: 244.58-244.59): 最適なShift = -0.0034, 最大相関 = 0.9827
# 区間 15 (Kilo: 244.58-244.60): 最適なShift = -0.0009, 最大相関 = 0.7323
# 区間 16 (Kilo: 244.59-244.61): 最適なShift = -0.0068, 最大相関 = 0.9137
# 区間 17 (Kilo: 244.59-244.62): 最適なShift = -0.0024, 最大相関 = 0.8960
# 区間 18 (Kilo: 244.61-244.62): 最適なShift = -0.0023, 最大相関 = 0.7651
# 区間 19 (Kilo: 244.61-244.63): 最適なShift = -0.0054, 最大相関 = 0.7985
# 区間 20 (Kilo: 244.62-244.63): 最適なShift = -0.0020, 最大相関 = 0.9221
# 区間 21 (Kilo: 244.62-244.64): 最適なShift = -0.0038, 最大相関 = -0.2006
# 区間 22 (Kilo: 244.63-244.64): 最適なShift = -0.0048, 最大相関 = 0.3808
# 区間 23 (Kilo: 244.63-244.65): 最適なShift = -0.0047, 最大相関 = 0.6993
# 区間 24 (Kilo: 244.64-244.66): 最適なShift = -0.0058, 最大相関 = 0.9291
# 区間 25 (Kilo: 244.65-244.66): 最適なShift = -0.0032, 最大相関 = 0.8557
# 区間 26 (Kilo: 244.65-244.67): 最適なShift = 0.0009, 最大相関 = 0.9996
# 区間 27 (Kilo: 244.66-244.67): 最適なShift = 0.0045, 最大相関 = -0.7014
# 区間 28 (Kilo: 244.67-244.68): 最適なShift = -0.0011, 最大相関 = 0.1211
# 区間 29 (Kilo: 244.67-244.69): 最適なShift = -0.0076, 最大相関 = 0.8244
# 区間 30 (Kilo: 244.67-244.70): 最適なShift = -0.0041, 最大相関 = 0.9289
# 区間 31 (Kilo: 244.68-244.71): 最適なShift = -0.0040, 最大相関 = 0.8659
# 区間 32 (Kilo: 244.69-244.71): 最適なShift = -0.0046, 最大相関 = 0.8374
# 区間 33 (Kilo: 244.70-244.72): 最適なShift = -0.0057, 最大相関 = 0.9097
# 区間 34 (Kilo: 244.71-244.72): 最適なShift = -0.0034, 最大相関 = 0.8297
# 区間 35 (Kilo: 244.72-244.72): 最適なShift = 0.0022, 最大相関 = 0.4761
# 区間 36 (Kilo: 244.72-244.73): 最適なShift = 0.0060, 最大相関 = -0.7471
# 区間 37 (Kilo: 244.73-244.74): 最適なShift = -0.0015, 最大相関 = -0.2617
# 区間 38 (Kilo: 244.73-244.75): 最適なShift = -0.0082, 最大相関 = 0.6335
# 区間 39 (Kilo: 244.73-244.76): 最適なShift = -0.0052, 最大相関 = 0.8766
# 区間 40 (Kilo: 244.74-244.76): 最適なShift = -0.0055, 最大相関 = 0.9620
# 区間 41 (Kilo: 244.75-244.77): 最適なShift = -0.0020, 最大相関 = -0.3669
# 区間 42 (Kilo: 244.76-244.77): 最適なShift = -0.0049, 最大相関 = 0.5819
# 区間 43 (Kilo: 244.76-244.78): 最適なShift = -0.0056, 最大相関 = 0.8631
# 区間 44 (Kilo: 244.77-244.79): 最適なShift = -0.0061, 最大相関 = 0.8857
# 区間 45 (Kilo: 244.78-244.81): 最適なShift = -0.0059, 最大相関 = 0.8416
# 区間 46 (Kilo: 244.79-244.81): 最適なShift = -0.0077, 最大相関 = 0.8035
# 区間 47 (Kilo: 244.80-244.82): 最適なShift = -0.0053, 最大相関 = 0.9672
# 区間 48 (Kilo: 244.81-244.84): 最適なShift = -0.0044, 最大相関 = 0.9389
# 区間 49 (Kilo: 244.82-244.84): 最適なShift = -0.0058, 最大相関 = 0.9446
# 区間 50 (Kilo: 244.83-244.85): 最適なShift = -0.0051, 最大相関 = 0.9065
# 区間 51 (Kilo: 244.84-244.86): 最適なShift = -0.0054, 最大相関 = 0.4313
# 区間 52 (Kilo: 244.84-244.87): 最適なShift = -0.0069, 最大相関 = 0.8666
# 区間 53 (Kilo: 244.85-244.88): 最適なShift = -0.0050, 最大相関 = 0.9824
# 区間 54 (Kilo: 244.86-244.88): 最適なShift = -0.0011, 最大相関 = 0.9994
# 区間 55 (Kilo: 244.87-244.88): 最適なShift = 0.0022, 最大相関 = -0.6913
# 区間 56 (Kilo: 244.88-244.89): 最適なShift = -0.0006, 最大相関 = 0.9421
# 区間 57 (Kilo: 244.88-244.90): 最適なShift = -0.0022, 最大相関 = 0.9240
# 区間 58 (Kilo: 244.88-244.90): 最適なShift = 0.0015, 最大相関 = 0.9690
# 区間 59 (Kilo: 244.90-244.91): 最適なShift = -0.0004, 最大相関 = -0.7511
# 区間 60 (Kilo: 244.90-244.91): 最適なShift = -0.0047, 最大相関 = 0.9346
# 区間 61 (Kilo: 244.90-244.92): 最適なShift = -0.0021, 最大相関 = 0.9076
# 区間 62 (Kilo: 244.91-244.93): 最適なShift = -0.0029, 最大相関 = 0.9954
# 区間 63 (Kilo: 244.92-244.93): 最適なShift = 0.0022, 最大相関 = -0.2168
# 区間 64 (Kilo: 244.93-244.94): 最適なShift = -0.0006, 最大相関 = 0.1088
# 区間 65 (Kilo: 244.93-244.95): 最適なShift = -0.0057, 最大相関 = 0.7737
# 区間 66 (Kilo: 244.93-244.96): 最適なShift = -0.0039, 最大相関 = 0.9039
# 区間 67 (Kilo: 244.94-244.97): 最適なShift = -0.0034, 最大相関 = 0.9539
# 区間 68 (Kilo: 244.96-244.97): 最適なShift = 0.0010, 最大相関 = 0.9722
# 区間 69 (Kilo: 244.97-244.98): 最適なShift = 0.0017, 最大相関 = 0.9926
# 区間 70 (Kilo: 244.97-244.98): 最適なShift = 0.0028, 最大相関 = 0.8799
# 区間 71 (Kilo: 244.98-244.99): 最適なShift = 0.0030, 最大相関 = 0.8642
# \n全振幅分析中...
#   data0を分析中...
#   data0で63個の振幅を検出
#   data1で73個の振幅を検出
#   data2で59個の振幅を検出
#   data3で61個の振幅を検出
#   data4で58個の振幅を検出
#   data5で57個の振幅を検出
#   data6で70個の振幅を検出
#   data7で69個の振幅を検出
#   data8で66個の振幅を検出
#   data9で62個の振幅を検出
#   data10で63個の振幅を検出
#   data11で67個の振幅を検出
#   data12で72個の振幅を検出
# 振幅データ 840 件を作成しました。
# \n=== キロ 244.738±0.005m の最大振幅統計 ===
# データセット数: 13
# 振幅範囲: 2.0448 - 3.3992
# 平均振幅: 2.4994
# 標準偏差: 0.3398
# \n波形連続プロットを生成中...

# %% [markdown]
# ## 完了
#
# 以上で全振幅分析が完了です！
#
# **出力内容：**
# 1. 時系列グラフ（最大振幅の時間変化）
# 2. 波形連続プロット（data0-data12の波形表示）
# 3. 統計情報（コンソール出力）
#
# 必要に応じて上記のセルを再実行して、異なるキロ地点で分析してください。
